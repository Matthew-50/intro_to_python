# %% [markdown]
# # Week 3: Further data manipulation

# %% [markdown]
# Import packages

# %%
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.14/site-packages (3.0.1)
# Requirement already satisfied: numpy>=2.3.3 in ./.venv/lib/python3.14/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# # Last week

# %%
print("Hellow World"2)
# Out:
#   Cell In[10], line 1
#     print("Hellow World"2)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# Import our data

# %%
df = pd.read_csv('/Users/matthew/ONS/intro_to_python/2011.csv', header = 1)

# %%
df.head(2)
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394745  E12000001              H                   5                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    1    4               1        2                 1       1             1
#
#    Religion  Economic Activity  Occupation  Industry  Hours worked per week  \
# 0         2                  5           8         2                     -9
# 1         2                  1           8         6                      4
#
#    Approximated Social Grade
# 0                          4
# 1                          3

# %% [markdown]
# Using and to combine something we previously did in two lines

# %%
df_students = df[df['Student'] == 1]

# %%
df_widowed_students = df_students[df_students['Marital Status'] == 5]

# %%
df_widowed_students.shape[0]
# Out:
# 109

# %% [markdown]
# On one line

# %%
df_widowed_students_two = df[(df['Student'] == 1) & (df['Marital Status'] == 5)]

# %%
df_widowed_students_two.shape[0]
# Out:
# 109

# %% [markdown]
# Which do you like better?
# The brackets above are used in exactly the same way that you would use brackets in normal math - just saying calculate this first, nothing to do with a tuple, no commas.

# %% [markdown]
# # This week

# %% [markdown]
# ## More on describing datasets

# %%
df.describe(include = 'all')
# Out:
#            Person ID     Region Residence Type  Family Composition  \
# count   5.697410e+05     569741         569741       569741.000000
# unique           NaN         10              2                 NaN
# top              NaN  E12000008              H                 NaN
# freq             NaN      88084         559087                 NaN
# mean    7.679353e+06        NaN            NaN            2.011870
# std     1.644702e+05        NaN            NaN            2.358788
# min     7.394483e+06        NaN            NaN           -9.000000
# 25%     7.536918e+06        NaN            NaN            2.000000
# 50%     7.679353e+06        NaN            NaN            2.000000
# 75%     7.821788e+06        NaN            NaN            3.000000
# max     7.964223e+06        NaN            NaN            6.000000
#
#         Population Base            Sex            Age  Marital Status  \
# count     569741.000000  569741.000000  569741.000000   569741.000000
# unique              NaN            NaN            NaN             NaN
# top                 NaN            NaN            NaN             NaN
# freq                NaN            NaN            NaN             NaN
# mean           1.018731       1.507550       3.978680        1.856201
# std            0.159058       0.499943       2.219494        1.125020
# min            1.000000       1.000000       1.000000        1.000000
# 25%            1.000000       1.000000       2.000000        1.000000
# 50%            1.000000       2.000000       4.000000        2.000000
# 75%            1.000000       2.000000       6.000000        2.000000
# max            3.000000       2.000000       8.000000        5.000000
#
#               Student  Country of Birth         Health   Ethnic Group  \
# count   569741.000000     569741.000000  569741.000000  569741.000000
# unique            NaN               NaN            NaN            NaN
# top               NaN               NaN            NaN            NaN
# freq              NaN               NaN            NaN            NaN
# mean         1.777904          1.016239       1.658324       1.191250
# std          0.415655          1.153095       1.486598       1.391858
# min          1.000000         -9.000000      -9.000000      -9.000000
# 25%          2.000000          1.000000       1.000000       1.000000
# 50%          2.000000          1.000000       2.000000       1.000000
# 75%          2.000000          1.000000       2.000000       1.000000
# max          2.000000          2.000000       5.000000       5.000000
#
#              Religion  Economic Activity     Occupation       Industry  \
# count   569741.000000      569741.000000  569741.000000  569741.000000
# unique            NaN                NaN            NaN            NaN
# top               NaN                NaN            NaN            NaN
# freq              NaN                NaN            NaN            NaN
# mean         2.419387           0.685597       1.240994       2.459844
# std          2.493064           5.265465       6.521825       7.398945
# min         -9.000000          -9.000000      -9.000000      -9.000000
# 25%          1.000000           1.000000      -9.000000      -9.000000
# 50%          2.000000           1.000000       3.000000       4.000000
# 75%          2.000000           5.000000       6.000000       8.000000
# max          9.000000           9.000000       9.000000      12.000000
#
#         Hours worked per week  Approximated Social Grade
# count           569741.000000              569741.000000
# unique                    NaN                        NaN
# top                       NaN                        NaN
# freq                      NaN                        NaN
# mean                -3.487095                   0.034130
# std                  5.887539                   4.862672
# min                 -9.000000                  -9.000000
# 25%                 -9.000000                   1.000000
# 50%                 -9.000000                   2.000000
# 75%                  3.000000                   3.000000
# max                  4.000000                   4.000000

# %%
df.mode() # similar to "top" above but relavant to more columms
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7959238  E12000008              H                   2                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    1               1        2                 1       1             1
#
#    Religion  Economic Activity  Occupation  Industry  Hours worked per week  \
# 0         2                  1          -9        -9                     -9
#
#    Approximated Social Grade
# 0                          2

# %% [markdown]
# ## Applying a function to a whole column

# %%
# Last week we spoke about changing column names using something called list comprehnsion
# df.columns = [col.lower() for col in list(df.columns)] 
# Thankfully applying  functions to every element in a dataframe column is way easier 

# Remember for strings we do x.function()
# for other types we normaly do function(x)

# %%
df['Region'] = df['Region'].str.lower() # have to tell pandas that its a string, its normally just a pointer to a string

# %%
df.head(2)
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  e12000001              H                   2                1
# 1    7394745  e12000001              H                   5                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    1    4               1        2                 1       1             1
#
#    Religion  Economic Activity  Occupation  Industry  Hours worked per week  \
# 0         2                  5           8         2                     -9
# 1         2                  1           8         6                      4
#
#    Approximated Social Grade
# 0                          4
# 1                          3

# %%
df['Region'] = df['Region'].str.upper()

# %%
df.head(2)
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394745  E12000001              H                   5                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    1    4               1        2                 1       1             1
#
#    Religion  Economic Activity  Occupation  Industry  Hours worked per week  \
# 0         2                  5           8         2                     -9
# 1         2                  1           8         6                      4
#
#    Approximated Social Grade
# 0                          4
# 1                          3

# %%
df['sqrt_age'] = df['Age'].apply(np.sqrt)

# %%
df.head(2)
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394745  E12000001              H                   5                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    1    4               1        2                 1       1             1
#
#    Religion  Economic Activity  Occupation  Industry  Hours worked per week  \
# 0         2                  5           8         2                     -9
# 1         2                  1           8         6                      4
#
#    Approximated Social Grade  sqrt_age
# 0                          4   2.44949
# 1                          3   2.00000

# %% [markdown]
# ## Combining columns

# %%
df['age_student'] = df['Age']*df['Student']

# %%
df.head()
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394745  E12000001              H                   5                1
# 2    7395066  E12000001              H                   3                1
# 3    7395329  E12000001              H                   3                1
# 4    7394712  E12000001              H                   3                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    1    4               1        2                 1       1             1
# 2    2    4               1        2                 1       1             1
# 3    2    2               1        2                 1       2             1
# 4    1    5               4        2                 1       1             1
#
#    Religion  Economic Activity  Occupation  Industry  Hours worked per week  \
# 0         2                  5           8         2                     -9
# 1         2                  1           8         6                      4
# 2         1                  1           6        11                      3
# 3         2                  1           7         7                      3
# 4         2                  1           1         4                      3
#
#    Approximated Social Grade  sqrt_age  age_student
# 0                          4  2.449490           12
# 1                          3  2.000000            8
# 2                          4  2.000000            8
# 3                          2  1.414214            4
# 4                          2  2.236068           10

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# Looking at a new type, a dictionary. Curley brackets with key: value pairs, each pair seperated by a comma

# %%
region_dict = {'E12000001': 'North East', 
'E12000002': 'North West', 
'E12000003': 'Yorkshire and the Humber', 
'E12000004': 'East Midlands', 
'E12000005': 'West Midlands', 
'E12000006': 'East of England', 
'E12000007': 'London', 
'E12000008': 'South East', 
'E12000009': 'South West',
'W92000004': 'Wales'}

# %%
type(region_dict)
# Out:
# dict

# %%
religion_dict = {1: 'No religion', 
2: 'Christian', 
3: 'Buddhist', 
4: 'Hindu', 
5: 'Jewish', 
6: 'Muslim', 
7: 'Sikh', 
8: 'Other religion', 
9: 'Not stated',
-9: 'No code required'}

# %%
type(religion_dict) # integers can be keys
# Out:
# dict

# %%
religion_dict[-9]
# Out:
# 'No code required'

# %%
eco_dict = {1 : "Active: Employee", 
                 2 : "Active: Self-employed", 
                 3 : "Active: Unemployed", 
                 4 : "Active: Full-time student",
                 5 : "Inactive: Retired", 
                 6 : "Inactive: Student", 
                 7 : "Inactive: Looking after home", 
                 8 : "Inactive: Disabled",
                 9 : "Inactive: Other",
                 -9: "No code required"}

# %% [markdown]
# ## Using a dictionary to change a column
#
# You cant use map with indexes

# %%
df['Region'] = df['Region'].map(region_dict)

# %%
df.head(2)
# Out:
#    Person ID      Region Residence Type  Family Composition  Population Base  \
# 0    7394816  North East              H                   2                1
# 1    7394745  North East              H                   5                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    1    4               1        2                 1       1             1
#
#    Religion  Economic Activity  Occupation  Industry  Hours worked per week  \
# 0         2                  5           8         2                     -9
# 1         2                  1           8         6                      4
#
#    Approximated Social Grade  sqrt_age  age_student
# 0                          4   2.44949           12
# 1                          3   2.00000            8

# %% [markdown]
# ## Is female

# %%
e = True
type(e)
# Out:
# bool

# %% [markdown]
# I want to build the group up to feeling confident writing code yourself.
# Question: Can you write some python code that makes a new column called something like "is_female" in the dataframe which has a value of True if the person is Female and a value of False if the person is Male?
# Break it down: First use the variables list to make a dictionary. What are the key-value pairs? Then use .map to make a new column.
# Remember in the 2011 Census we coded female as 2 and Male as 1

# %%
sex_dict = {1:False, 2:True}

# %%
df['Female'] = df['Sex'].map(sex_dict)

# %% [markdown]
# # Week 4
