# %% [markdown]
# # Week 3: Further data manipulation

# %% [markdown]
# Import packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Last week

# %% [markdown]
# Import our data

# %%
df = pd.read_csv('/Users/matthew/ONS/intro_to_python/2011.csv', header = 1)

# %%
df.head(2)
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394816    E12000001              H                   2                1    2
# 7394745    E12000001              H                   5                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      6               2        2                 1       2
# 7394745      4               1        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
#
#            Hours worked per week  Approximated Social Grade
# Person ID
# 7394816                       -9                          4
# 7394745                        4                          3

# %% [markdown]
# Using and to combine something we previously did in two lines

# %%
df_students = df[df['Student'] == 1]

# %%
df_widowed_students = df_students[df_students['Marital Status'] == 5]

# %%
df_widowed_students.shape[0]
# Out:
# 109

# %% [markdown]
# On one line

# %%
df_widowed_students_two = df[(df['Student'] == 1) & (df['Marital Status'] == 5)]

# %%
df_widowed_students_two.shape[0]
# Out:
# 109

# %% [markdown]
# Which do you like better?
# The brackets above are used in exactly the same way that you would use brackets in normal math - just saying calculate this first, nothing to do with a tuple, no commas.

# %% [markdown]
# # This week

# %% [markdown]
# ## More on describing datasets

# %%
df.describe(include = 'all')
# Out:
#            Person ID     Region Residence Type  Family Composition  \
# count   5.697410e+05     569741         569741       569741.000000
# unique           NaN         10              2                 NaN
# top              NaN  E12000008              H                 NaN
# freq             NaN      88084         559087                 NaN
# mean    7.679353e+06        NaN            NaN            2.011870
# std     1.644702e+05        NaN            NaN            2.358788
# min     7.394483e+06        NaN            NaN           -9.000000
# 25%     7.536918e+06        NaN            NaN            2.000000
# 50%     7.679353e+06        NaN            NaN            2.000000
# 75%     7.821788e+06        NaN            NaN            3.000000
# max     7.964223e+06        NaN            NaN            6.000000
#
#         Population Base            Sex            Age  Marital Status  \
# count     569741.000000  569741.000000  569741.000000   569741.000000
# unique              NaN            NaN            NaN             NaN
# top                 NaN            NaN            NaN             NaN
# freq                NaN            NaN            NaN             NaN
# mean           1.018731       1.507550       3.978680        1.856201
# std            0.159058       0.499943       2.219494        1.125020
# min            1.000000       1.000000       1.000000        1.000000
# 25%            1.000000       1.000000       2.000000        1.000000
# 50%            1.000000       2.000000       4.000000        2.000000
# 75%            1.000000       2.000000       6.000000        2.000000
# max            3.000000       2.000000       8.000000        5.000000
#
#               Student  Country of Birth         Health   Ethnic Group  \
# count   569741.000000     569741.000000  569741.000000  569741.000000
# unique            NaN               NaN            NaN            NaN
# top               NaN               NaN            NaN            NaN
# freq              NaN               NaN            NaN            NaN
# mean         1.777904          1.016239       1.658324       1.191250
# std          0.415655          1.153095       1.486598       1.391858
# min          1.000000         -9.000000      -9.000000      -9.000000
# 25%          2.000000          1.000000       1.000000       1.000000
# 50%          2.000000          1.000000       2.000000       1.000000
# 75%          2.000000          1.000000       2.000000       1.000000
# max          2.000000          2.000000       5.000000       5.000000
#
#              Religion  Economic Activity     Occupation       Industry  \
# count   569741.000000      569741.000000  569741.000000  569741.000000
# unique            NaN                NaN            NaN            NaN
# top               NaN                NaN            NaN            NaN
# freq              NaN                NaN            NaN            NaN
# mean         2.419387           0.685597       1.240994       2.459844
# std          2.493064           5.265465       6.521825       7.398945
# min         -9.000000          -9.000000      -9.000000      -9.000000
# 25%          1.000000           1.000000      -9.000000      -9.000000
# 50%          2.000000           1.000000       3.000000       4.000000
# 75%          2.000000           5.000000       6.000000       8.000000
# max          9.000000           9.000000       9.000000      12.000000
#
#         Hours worked per week  Approximated Social Grade
# count           569741.000000              569741.000000
# unique                    NaN                        NaN
# top                       NaN                        NaN
# freq                      NaN                        NaN
# mean                -3.487095                   0.034130
# std                  5.887539                   4.862672
# min                 -9.000000                  -9.000000
# 25%                 -9.000000                   1.000000
# 50%                 -9.000000                   2.000000
# 75%                  3.000000                   3.000000
# max                  4.000000                   4.000000

# %%
df.mode() # similar to "top" above but relavant to more columms
# Out:
#       Region Residence Type  Family Composition  Population Base  Sex  Age  \
# 0  E12000008              H                   2                1    2    1
#
#    Marital Status  Student  Country of Birth  Health  Ethnic Group  Religion  \
# 0               1        2                 1       1             1         2
#
#    Economic Activity  Occupation  Industry  Hours worked per week  \
# 0                  1          -9        -9                     -9
#
#    Approximated Social Grade
# 0                          2

# %% [markdown]
# ## Applying a function to a whole column

# %%
# Last week we spoke about changing column names using something called list comprehnsion
# df.columns = [col.lower() for col in list(df.columns)] 
# Thankfully applying  functions to every element in a dataframe column is way easier 

# Remember for strings we do x.function()
# for other types we normaly do function(x)

# %%
df['Region'] = df['Region'].str.lower() # have to tell pandas that its a string, its normally just a pointer to a string

# %%
df.head(2)
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394816    e12000001              H                   2                1    2
# 7394745    e12000001              H                   5                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      6               2        2                 1       2
# 7394745      4               1        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
#
#            Hours worked per week  Approximated Social Grade
# Person ID
# 7394816                       -9                          4
# 7394745                        4                          3

# %%
df['Region'] = df['Region'].str.upper()

# %%
df.head(2)
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394816    E12000001              H                   2                1    2
# 7394745    E12000001              H                   5                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      6               2        2                 1       2
# 7394745      4               1        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
#
#            Hours worked per week  Approximated Social Grade
# Person ID
# 7394816                       -9                          4
# 7394745                        4                          3

# %%
df['sqrt_age'] = df['Age'].apply(np.sqrt)

# %%
df.head(2)
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394816    E12000001              H                   2                1    2
# 7394745    E12000001              H                   5                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      6               2        2                 1       2
# 7394745      4               1        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
#
#            Hours worked per week  Approximated Social Grade  sqrt_age
# Person ID
# 7394816                       -9                          4   2.44949
# 7394745                        4                          3   2.00000

# %% [markdown]
# ## Combining columns

# %%
df['age_student'] = df['Age']*df['Student']

# %%
df.head()
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394816    E12000001              H                   2                1    2
# 7394745    E12000001              H                   5                1    1
# 7395066    E12000001              H                   3                1    2
# 7395329    E12000001              H                   3                1    2
# 7394712    E12000001              H                   3                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      6               2        2                 1       2
# 7394745      4               1        2                 1       1
# 7395066      4               1        2                 1       1
# 7395329      2               1        2                 1       2
# 7394712      5               4        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
# 7395066               1         1                  1           6        11
# 7395329               1         2                  1           7         7
# 7394712               1         2                  1           1         4
#
#            Hours worked per week  Approximated Social Grade  sqrt_age  \
# Person ID
# 7394816                       -9                          4  2.449490
# 7394745                        4                          3  2.000000
# 7395066                        3                          4  2.000000
# 7395329                        3                          2  1.414214
# 7394712                        3                          2  2.236068
#
#            age_student
# Person ID
# 7394816             12
# 7394745              8
# 7395066              8
# 7395329              4
# 7394712             10

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# Looking at a new type, a dictionary. Curley brackets with key: value pairs, each pair seperated by a comma

# %%
region_dict = {'E12000001': 'North East', 
'E12000002': 'North West', 
'E12000003': 'Yorkshire and the Humber', 
'E12000004': 'East Midlands', 
'E12000005': 'West Midlands', 
'E12000006': 'East of England', 
'E12000007': 'London', 
'E12000008': 'South East', 
'E12000009': 'South West',
'W92000004': 'Wales'}

# %%
type(region_dict)
# Out:
# dict

# %%
religion_dict = {1: 'No religion', 
2: 'Christian', 
3: 'Buddhist', 
4: 'Hindu', 
5: 'Jewish', 
6: 'Muslim', 
7: 'Sikh', 
8: 'Other religion', 
9: 'Not stated',
-9: 'No code required'}

# %%
type(religion_dict) # integers can be keys
# Out:
# dict

# %%
religion_dict[-9]
# Out:
# 'No code required'

# %%
eco_dict = {1 : "Active: Employee", 
                 2 : "Active: Self-employed", 
                 3 : "Active: Unemployed", 
                 4 : "Active: Full-time student",
                 5 : "Inactive: Retired", 
                 6 : "Inactive: Student", 
                 7 : "Inactive: Looking after home", 
                 8 : "Inactive: Disabled",
                 9 : "Inactive: Other",
                 -9: "No code required"}

# %% [markdown]
# ## Using a dictionary to change a column
#
# You cant use map with indexes

# %%
df['Region'] = df['Region'].map(region_dict)

# %%
df.head(2)
# Out:
#                Region Residence Type  Family Composition  Population Base  \
# Person ID
# 7394816    North East              H                   2                1
# 7394745    North East              H                   5                1
#
#            Sex  Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      2    6               2        2                 1       2
# 7394745      1    4               1        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
#
#            Hours worked per week  Approximated Social Grade  sqrt_age  \
# Person ID
# 7394816                       -9                          4   2.44949
# 7394745                        4                          3   2.00000
#
#            age_student
# Person ID
# 7394816             12
# 7394745              8

# %% [markdown]
# ## Is female

# %%
e = True
type(e)
# Out:
# bool

# %% [markdown]
# I want to build the group up to feeling confident writing code yourself.
# Question: Can you write some python code that makes a new column in the dataframe which has a value of True if the person is Female?
# Break it down: First use the variables list to make a dictionary. What are the key-value pairs? Then use .map to make a new column.

# %%
sex_dict = {1:False, 2:True}

# %%
df['Female'] = df['Sex'].map(sex_dict)

# %%
df.head()
# Out:
#                Region Residence Type  Family Composition  Population Base  \
# Person ID
# 7394816    North East              H                   2                1
# 7394745    North East              H                   5                1
# 7395066    North East              H                   3                1
# 7395329    North East              H                   3                1
# 7394712    North East              H                   3                1
#
#            Sex  Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      2    6               2        2                 1       2
# 7394745      1    4               1        2                 1       1
# 7395066      2    4               1        2                 1       1
# 7395329      2    2               1        2                 1       2
# 7394712      1    5               4        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
# 7395066               1         1                  1           6        11
# 7395329               1         2                  1           7         7
# 7394712               1         2                  1           1         4
#
#            Hours worked per week  Approximated Social Grade  sqrt_age  \
# Person ID
# 7394816                       -9                          4  2.449490
# 7394745                        4                          3  2.000000
# 7395066                        3                          4  2.000000
# 7395329                        3                          2  1.414214
# 7394712                        3                          2  2.236068
#
#            age_student  Female
# Person ID
# 7394816             12    True
# 7394745              8   False
# 7395066              8    True
# 7395329              4    True
# 7394712             10   False

# %% [markdown]
# # Week 4

# %% [markdown]
# ## Aggregate tables
#
# In the "possibilities for exploring the data" pdf. Figure 1 on page 3 has the title: "Sex differences among unemployed, employees and self-employed individuals."
# 1. Restrict the dataset to the two columns we want
# 2. Groupby - decide which column to group on

# %%
df['Economic Activity'] = df['Economic Activity'].map(eco_dict)

# %%
sex_dict_mf = {1: 'Male', 2:'Female'}

# %%
df['Sex'] = df['Sex'].map(sex_dict_mf)

# %%
gb_eco_sex = df.groupby(["Economic Activity", "Sex"]).size().unstack()
gb_eco_sex
# Out:
# Sex                           Female    Male
# Economic Activity
# Active: Employee              108028  107997
# Active: Full-time student       7530    6587
# Active: Self-employed          11842   28790
# Active: Unemployed              7349   10760
# Inactive: Disabled              8769    9222
# Inactive: Looking after home   16230    1715
# Inactive: Other                 5604    4464
# Inactive: Retired              56875   40605
# Inactive: Student              12136   12620
# No code required               54809   57809

# %% [markdown]
# ### a little plot

# %%
# !pip3 install matplotlib
from matplotlib.pyplot import plot
print(gb_eco_sex)
gb_eco_sex.plot(kind = 'bar')
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp314-cp314-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp314-cp314-macosx_10_15_universal2.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp314-cp314-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.14/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.14/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp314-cp314-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp314-cp314-macosx_11_0_arm64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 30.5 MB/s  0:00:00 eta 0:00:01
# Downloading contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (273 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp314-cp314-macosx_10_15_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 29.1 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp314-cp314-macosx_11_0_arm64.whl (64 kB)
# Downloading pillow-12.1.1-cp314-cp314-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 29.8 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
# Matplotlib is building the font cache; this may take a moment.
# Sex                           Female    Male
# Economic Activity
# Active: Employee              108028  107997
# Active: Full-time student       7530    6587
# Active: Self-employed          11842   28790
# Active: Unemployed              7349   10760
# Inactive: Disabled              8769    9222
# Inactive: Looking after home   16230    1715
# Inactive: Other                 5604    4464
# Inactive: Retired              56875   40605
# Inactive: Student              12136   12620
# No code required               54809   57809
# <Axes: xlabel='Economic Activity'>

# %% [markdown]
# Question what are the differences between the plots?
# 1. restricted economic activity to only certain active ones
# 2. percentage
# 3. ignore superficial ones like colour & position of bars for now

# %%
# Restrict to economically active (1, 2, 3), using tools that we have before
df_active_eco_sex = df[df['Economic Activity'].isin(["Active: Employee", "Active: Self-employed", "Active: Unemployed", ])]

# %%
active_ecos = df['Economic Activity'][df['Economic Activity'].str.startswith('Active')].unique()

# %%
list(Cactive_ecos)
# Out:
# ['Active: Employee',
#  'Active: Full-time student',
#  'Active: Self-employed',
#  'Active: Unemployed']

# %%
gb_active_eco_sex = df_active_eco_sex.groupby(["Economic Activity", "Sex"]).size().unstack()

# %%
type(gb_active_eco_sex)
# Out:
# pandas.core.frame.DataFrame

# %%
# Need mroe measures - porprtion of each bar, which gender is larger and by how much
print(gb_active_eco_sex)
gb_active_eco_sex.plot(kind = 'bar')
# Out:
# Sex                    Female    Male
# Economic Activity
# Active: Employee       108028  107997
# Active: Self-employed   11842   28790
# Active: Unemployed       7349   10760
# <Axes: xlabel='Economic Activity'>

# %%
type(gb_active_eco_sex)
# Out:
# pandas.core.frame.DataFrame

# %%
gb_active_eco_sex.head(6)
# Out:
# Sex                    Female    Male
# Economic Activity
# Active: Employee       108028  107997
# Active: Self-employed   11842   28790
# Active: Unemployed       7349   10760

# %%
gb_active_eco_sex = gb_active_eco_sex.rename({0:'count'})

# %%
gb_active_eco = df_active_eco_sex.groupby("Economic Activity").size()

# %%
gb_active_eco.head()
# Out:
# Economic Activity
# Active: Employee         216025
# Active: Self-employed     40632
# Active: Unemployed        18109
# dtype: int64

# %%
gb_active_eco = gb_active_eco.rename('people_sum')

# %%
gb_active_eco.head()
# Out:
# Economic Activity
# Active: Employee         216025
# Active: Self-employed     40632
# Active: Unemployed        18109
# Name: people_sum, dtype: int64

# %%
df_sum = gb_active_eco_sex.join(gb_active_eco, on=['Economic Activity'])

# %%
df_sum.head(6)
# Out:
#                        Female    Male  people_sum
# Economic Activity
# Active: Employee       108028  107997      216025
# Active: Self-employed   11842   28790       40632
# Active: Unemployed       7349   10760       18109

# %% [markdown]
# ### F percent and M percent

# %%
df_sum['F_percent'] = 100*df_sum['Female']/df_sum['people_sum']
df_sum['M_percent'] = 100*df_sum['Male']/df_sum['people_sum']

# %%
df_sum.head(6)
# Out:
#                        Female    Male  people_sum  F_percent  M_percent
# Economic Activity
# Active: Employee       108028  107997      216025  50.007175  49.992825
# Active: Self-employed   11842   28790       40632  29.144517  70.855483
# Active: Unemployed       7349   10760       18109  40.582031  59.417969

# %%
print(df_sum[['F_percent', 'M_percent']])
df_sum[['F_percent', 'M_percent']].plot(kind = 'bar')
# Out:
#                        F_percent  M_percent
# Economic Activity
# Active: Employee       50.007175  49.992825
# Active: Self-employed  29.144517  70.855483
# Active: Unemployed     40.582031  59.417969
# <Axes: xlabel='Economic Activity'>

# %% [markdown]
# ## As a function

# %%
def plot_agg_eco_sex(dataframe = df, variable_one = "Economic Activity", variable_two = "Sex"): # for chat gpt
    
    # Charts need bigger labelling
    print(dataframe.describe())
    df_to_plot = dataframe.groupby([variable_one, variable_two]).size().unstack()
    return df_to_plot.plot(kind = 'bar')

# %%
plot_agg_eco_sex(dataframe = df, variable_one = "Economic Activity", variable_two = "Residence Type")
# Out:
#           Person ID  Family Composition  Population Base            Age  \
# count  5.697410e+05       569741.000000    569741.000000  569741.000000
# mean   7.679353e+06            2.011870         1.018731       3.978680
# std    1.644702e+05            2.358788         0.159058       2.219494
# min    7.394483e+06           -9.000000         1.000000       1.000000
# 25%    7.536918e+06            2.000000         1.000000       2.000000
# 50%    7.679353e+06            2.000000         1.000000       4.000000
# 75%    7.821788e+06            3.000000         1.000000       6.000000
# max    7.964223e+06            6.000000         3.000000       8.000000
#
#        Marital Status        Student  Country of Birth         Health  \
# count   569741.000000  569741.000000     569741.000000  569741.000000
# mean         1.856201       1.777904          1.016239       1.658324
# std          1.125020       0.415655          1.153095       1.486598
# min          1.000000       1.000000         -9.000000      -9.000000
# 25%          1.000000       2.000000          1.000000       1.000000
# 50%          2.000000       2.000000          1.000000       2.000000
# 75%          2.000000       2.000000          1.000000       2.000000
# max          5.000000       2.000000          2.000000       5.000000
#
#         Ethnic Group       Religion     Occupation       Industry  \
# count  569741.000000  569741.000000  569741.000000  569741.000000
# mean        1.191250       2.419387       1.240994       2.459844
# std         1.391858       2.493064       6.521825       7.398945
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%         1.000000       1.000000      -9.000000      -9.000000
# 50%         1.000000       2.000000       3.000000       4.000000
# 75%         1.000000       2.000000       6.000000       8.000000
# max         5.000000       9.000000       9.000000      12.000000
#
#        Hours worked per week  Approximated Social Grade       sqrt_age  \
# count          569741.000000              569741.000000  569741.000000
# mean               -3.487095                   0.034130       1.904640
# std                 5.887539                   4.862672       0.592474
# min                -9.000000                  -9.000000       1.000000
# 25%                -9.000000                   1.000000       1.414214
# 50%                -9.000000                   2.000000       2.000000
# 75%                 3.000000                   3.000000       2.449490
# max                 4.000000                   4.000000       2.828427
#
#          age_student
# count  569741.000000
# mean        7.640805
# std         4.790987
# min         1.000000
# 25%         2.000000
# 50%         8.000000
# 75%        12.000000
# max        16.000000
# <Axes: xlabel='Economic Activity'>

# %%
import matplotlib.pyplot as plt
# Write a hash to denote a comment
def plot_agg_eco_sex(
    dataframe: pd.DataFrame,
    variable_one: str = "Economic Activity",
    variable_two: str = "Sex"
) -> plt.Axes:
    """
    Plots a bar chart showing the aggregate count of entries in a DataFrame, 
    grouped by two specified variables.

    Parameters:
    - dataframe: DataFrame
        The input data frame containing the data to plot.
    - variable_one: str, optional
        The column name in the data frame representing the first category (default is "Economic Activity").
    - variable_two: str, optional
        The column name in the data frame representing the second category (default is "Sex").

    Returns:
    - plt.Axes
        The matplotlib Axes object containing the plot.
    """
    df_to_plot = dataframe.groupby([variable_one, variable_two]).size().unstack()
    return df_to_plot.plot(kind='bar')

# %%
plot_agg_eco_sex(df, 'Economic Activity', 'Sex')

# %% [markdown]
# ## Correlations

# %%
# !pip3 install seaborn
import seaborn as sns
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./.venv/lib/python3.14/site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in ./.venv/lib/python3.14/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.venv/lib/python3.14/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
df_down = df[['Age', 'Marital Status', 'Student']]

# %%
print(df_down.corr())
sns.heatmap(df_down.corr(), annot = True) # doesnt really make sense
# Out:
#                      Age  Marital Status   Student
# Age             1.000000        0.639171  0.614706
# Marital Status  0.639171        1.000000  0.390542
# Student         0.614706        0.390542  1.000000
# <Axes: >

# %%
# 

gb_work_hrs_sex = df_active_eco_sex.groupby(["Hours Worked per Week", "Sex Headers"]).size().unstack()
gb_work_hrs_sex
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 3
#       1 #
# ----> 3 gb_work_hrs_sex = df_active_eco_sex.groupby(["Hours Worked per Week", "Sex Headers"]).size().unstack()
#       4 gb_work_hrs_sex
#
# File ~/ONS/intro_to_python/.venv/lib/python3.14/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~/ONS/intro_to_python/.venv/lib/python3.14/site-packages/pandas/core/frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
#   10815     raise TypeError("You have to supply one of 'by' and 'level'")
# > 10817 return DataFrameGroupBy(
#   10818     obj=self,
#   10819     keys=by,
#   10820     level=level,
#   10821     as_index=as_index,
#   10822     sort=sort,
#   10823     group_keys=group_keys,
#   10824     observed=observed,
#   10825     dropna=dropna,
#   10826 )
#
# File ~/ONS/intro_to_python/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File ~/ONS/intro_to_python/.venv/lib/python3.14/site-packages/pandas/core/groupby/grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'Hours Worked per Week'
