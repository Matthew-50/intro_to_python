# %% [markdown]
# # Week 2

# %%
# comment

# %%
a = 1
a

# %%
a

# %%
name = 'michaela   '

# %%
name = name.strip()

# %%
name

# %%
name = name.capitalize()

# %%
name

# %%
type(name)

# %%
type(a)

# %%
# b = 2

# %%
import pandas as pd

# %%
df = pd.read_csv('2011.csv', header = 1, index_col = "Person ID")

# %%
df.head()

# %%
df.tail()

# %%
type(df)

# %%
df.dtypes

# %%
df.shape

# %%
df.describe(include = 'all')

# %%
df.columns

# %%
type(df.columns)

# %%
student_column = df['Student']

# %%
student_column

# %%
# ==, >, >=, <, <=, !=

# %%
students = df[df['Student'] == 1]

# %%
students.head()

# %%
students.shape

# %%
type(students.shape)

# %%
df.shape[0]

# %%
students.shape[0]/df.shape[0]

# %%
str(round(students.shape[0]/df.shape[0], 2)*100) + '%'

# %%
widowed_students = students[students['Marital Status'] == 5]

# %%
widowed_students.shape

# %%
widowed_students.shape[0]/df.shape[0]

# %%
students['Marital Status'] == 5

# %%
widowed_students.to_csv('widowed_students.csv')
